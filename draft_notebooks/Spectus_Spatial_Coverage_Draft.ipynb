# %%
import contextily as ctx
import geopandas as gpd
import matplotlib.pyplot as plt
import os
import pandas as pd
from shapely.geometry import LineString

# directory = './data/Spectus/Lyra_Processed/split_by_user'

df_spectus = pd.read_csv(f'../data/Spectus/Lyra_Processed/Seattle_2000_compressed_trips.csv')

print(len(df_spectus))

def plot_trips_on_map(start_index=None,
                      end_index=None,
                      base_path='data/Spectus/Lyra_Processed/split_by_user/user_EXAMPLE.csv'):

    points_dataframe = pd.read_csv(base_path)
    points_dataframe = points_dataframe[points_dataframe['traj_id'] != -99]
    points_dataframe = points_dataframe.rename(columns={'orig_lat': 'lat', 'orig_long': 'lng', 'datetime': 'timestamp'})
    points_dataframe['timestamp'] = pd.to_datetime(points_dataframe['timestamp'])

    points_geodataframe = gpd.GeoDataFrame(points_dataframe,
                                           geometry=gpd.points_from_xy(points_dataframe.lng,
                                             points_dataframe.lat))
    points_geodataframe.crs = "EPSG:4326"  # For lat/lon data
    points_geodataframe = points_geodataframe.to_crs(epsg=3857)

    fig, ax = plt.subplots(dpi=200)

    minx, miny, maxx, maxy = points_geodataframe.total_bounds
    ax.set_xlim(minx, maxx)
    ax.set_ylim(miny, maxy)

    count = 0
    for value, group in points_geodataframe.groupby('traj_id'):
        if end_index != None and count >= end_index:
            break
        if start_index != None and count < start_index:
            count += 1
            continue

        print(f'Processing Trajectory {value}')

        line = LineString(points_geodataframe.geometry.tolist())
        line_gdf = gpd.GeoDataFrame(geometry=[line], crs=points_geodataframe.crs)
        line_gdf.plot(ax=ax, color="black", linewidth=0.1, zorder=3)

        count += 1

    ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)

    plt.show()

plot_trips_on_map(start_index=0, end_index=306)
# Out:
# 529414
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 55
#      51     ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)
#      52
#      53     plt.show()
#      54
# ---> 55 plot_trips_on_map(start_index=0, end_index=306)
#
# Cell In[1], line 18, in plot_trips_on_map(start_index, end_index, base_path)
#      14 def plot_trips_on_map(start_index=None,
#      15                       end_index=None,
#      16                       base_path='data/Spectus/Lyra_Processed/split_by_user/user_EXAMPLE.csv'):
#      17
# ---> 18     points_dataframe = pd.read_csv(base_path)
#      19     points_dataframe = points_dataframe[points_dataframe['traj_id'] != -99]
#      20     points_dataframe = points_dataframe.rename(columns={'orig_lat': 'lat', 'orig_long': 'lng', 'datetime': 'timestamp'})
#      21     points_dataframe['timestamp'] = pd.to_datetime(points_dataframe['timestamp'])
#
# File ~/.pyenv/versions/mode_analysis/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/mode_analysis/lib/python3.12/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~/.pyenv/versions/mode_analysis/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~/.pyenv/versions/mode_analysis/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~/.pyenv/versions/mode_analysis/lib/python3.12/site-packages/pandas/io/common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/Spectus/Lyra_Processed/split_by_user/user_EXAMPLE.csv'

# %%
import contextily as ctx
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from shapely.geometry import box, LineString

# directory = './data/Spectus/Lyra_Processed/split_by_user'

def plot_trips_on_map(start_index=None,
                      end_index=None,
                      base_path='./data/Spectus/Lyra_Processed/Seattle_2000_compressed_trips.csv'):

    points_dataframe = pd.read_csv(base_path)
    points_dataframe = points_dataframe[points_dataframe['traj_id'] != -99]
    points_dataframe = points_dataframe.rename(columns={'start_lat': 'lat', 'start_lon': 'lng'})

    points_geodataframe = gpd.GeoDataFrame(points_dataframe,
                                           geometry=gpd.points_from_xy(points_dataframe.lng,
                                             points_dataframe.lat))
    points_geodataframe.crs = "EPSG:4326"  # For lat/lon data
    # points_geodataframe = points_geodataframe.to_crs(epsg=3857)

    fig, ax = plt.subplots(dpi=200)

    # minx, miny, maxx, maxy = points_geodataframe.total_bounds
    minx, maxx = -122.60, -122.00   # your desired longitude range
    miny, maxy = 47.1, 48.0     # your desired latitude range
    ax.set_xlim(minx, maxx)
    ax.set_ylim(miny, maxy)
    mid_lat = (miny + maxy) / 2
    ax.set_aspect(1 / np.cos(np.radians(mid_lat)))

    # points_dataframe.plot(ax=ax, color="black", zorder=5)
    # count = 0
    # for index, row in points_geodataframe.iterrows():
    #     if end_index != None and count >= end_index:
    #         break
    #     if start_index != None and count < start_index:
    #         count += 1
    #         continue
    #
    #     print(f'Processing Trajectory {row['traj_id']}')
    #     print(f'lat: {row['lat']}, lon: {row['lng']}')
    #     ax.scatter(row.geometry.x, row.geometry.y, color="yellow", s=1, zorder=4)
    #
    #     count += 1
    subset = points_geodataframe.iloc[start_index:end_index]
    ax.scatter(subset.geometry.x, subset.geometry.y, color="mediumseagreen", s=1, zorder=1)

    ctx.add_basemap(ax, crs="EPSG:4326", source=ctx.providers.OpenStreetMap.Mapnik)
    ax.texts[-1].set_position((0.01, 0.01))

    plt.show()

plot_trips_on_map(start_index=0, end_index=10000)

# %%
import contextily as ctx
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from shapely.geometry import box, LineString

# directory = './data/Spectus/Lyra_Processed/split_by_user'

def plot_trips_on_map(start_index=None,
                      end_index=None,
                      base_path='./data/Spectus/Lyra_Processed/Seattle_2000_compressed_trips.csv'):

    points_dataframe = pd.read_csv(base_path)
    points_dataframe = points_dataframe[points_dataframe['traj_id'] != -99]
    points_dataframe = points_dataframe.rename(columns={'end_lat': 'lat', 'end_lon': 'lng'})

    points_geodataframe = gpd.GeoDataFrame(points_dataframe,
                                           geometry=gpd.points_from_xy(points_dataframe.lng,
                                             points_dataframe.lat))
    points_geodataframe.crs = "EPSG:4326"  # For lat/lon data
    # points_geodataframe = points_geodataframe.to_crs(epsg=3857)

    fig, ax = plt.subplots(dpi=200)

    # minx, miny, maxx, maxy = points_geodataframe.total_bounds
    minx, maxx = -122.60, -122.00   # your desired longitude range
    miny, maxy = 47.1, 48.0     # your desired latitude range
    ax.set_xlim(minx, maxx)
    ax.set_ylim(miny, maxy)
    mid_lat = (miny + maxy) / 2
    ax.set_aspect(1 / np.cos(np.radians(mid_lat)))

    # points_dataframe.plot(ax=ax, color="black", zorder=5)
    # count = 0
    # for index, row in points_geodataframe.iterrows():
    #     if end_index != None and count >= end_index:
    #         break
    #     if start_index != None and count < start_index:
    #         count += 1
    #         continue
    #
    #     print(f'Processing Trajectory {row['traj_id']}')
    #     print(f'lat: {row['lat']}, lon: {row['lng']}')
    #     ax.scatter(row.geometry.x, row.geometry.y, color="yellow", s=1, zorder=4)
    #
    #     count += 1
    subset = points_geodataframe.iloc[start_index:end_index]
    ax.scatter(subset.geometry.x, subset.geometry.y, color="orangered", s=1, zorder=1)

    ctx.add_basemap(ax, crs="EPSG:4326", source=ctx.providers.OpenStreetMap.Mapnik)
    ax.texts[-1].set_position((0.01, 0.01))

    plt.show()

plot_trips_on_map(start_index=0, end_index=10000)

# %%
import contextily as ctx
import geopandas as gpd
from matplotlib.collections import LineCollection
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from shapely.geometry import box, LineString

# directory = './data/Spectus/Lyra_Processed/split_by_user'

def plot_trips_on_map(start_index=None,
                      end_index=None,
                      base_path='./data/Spectus/Lyra_Processed/Seattle_2000_compressed_trips.csv'):

    points_dataframe = pd.read_csv(base_path)
    points_dataframe = points_dataframe[points_dataframe['traj_id'] != -99]
    points_dataframe = points_dataframe.iloc[start_index:end_index]
    segments = np.column_stack([
        points_dataframe.start_lon, points_dataframe.start_lat, points_dataframe.end_lon, points_dataframe.end_lat
    ]).reshape(-1, 2, 2)
    # points_dataframe = points_dataframe.rename(columns={'end_lat': 'lat', 'end_lon': 'lng'})

    # points_geodataframe = gpd.GeoDataFrame(points_dataframe,
    #                                        geometry=gpd.points_from_xy(points_dataframe.lng,
    #                                          points_dataframe.lat))
    # points_geodataframe.crs = "EPSG:4326"  # For lat/lon data

    fig, ax = plt.subplots(dpi=200)

    # minx, miny, maxx, maxy = points_geodataframe.total_bounds
    minx, maxx = -122.60, -122.00   # your desired longitude range
    miny, maxy = 47.1, 48.0     # your desired latitude range
    ax.set_xlim(minx, maxx)
    ax.set_ylim(miny, maxy)
    mid_lat = (miny + maxy) / 2
    ax.set_aspect(1 / np.cos(np.radians(mid_lat)))

    # points_dataframe.plot(ax=ax, color="black", zorder=5)
    # count = 0
    # for index, row in points_geodataframe.iterrows():
    #     if end_index != None and count >= end_index:
    #         break
    #     if start_index != None and count < start_index:
    #         count += 1
    #         continue
    #
    #     print(f'Processing Trajectory {row['traj_id']}')
    #     print(f'lat: {row['lat']}, lon: {row['lng']}')
    #     ax.scatter(row.geometry.x, row.geometry.y, color="yellow", s=1, zorder=4)
    #
    #     count += 1
    # subset = points_geodataframe.iloc[start_index:end_index]
    # ax.scatter(subset.geometry.x, subset.geometry.y, color="orangered", s=1, zorder=1)

    lc = LineCollection(segments, colors="black", linewidths=1, zorder=1)
    ax.add_collection(lc)

    ctx.add_basemap(ax, crs="EPSG:4326", source=ctx.providers.OpenStreetMap.Mapnik)
    ax.texts[-1].set_position((0.01, 0.01))

    plt.show()

plot_trips_on_map(start_index=0, end_index=100)

# %%
import geopandas as gpd

cbg_gdf = gpd.read_file("../data/Seattle_neighborhoods/nma_nhoods_main.shp")
cbg_gdf = cbg_gdf.to_crs("EPSG:4326")  # match your points' CRS

# print(cbg_gdf.columns.tolist())

# start_index = 0
# end_index = 10000
points_dataframe = pd.read_csv('../data/Spectus/Lyra_Processed/Seattle_2000_compressed_trips.csv')
points_dataframe = points_dataframe[points_dataframe['traj_id'] != -99]
# points_dataframe = points_dataframe.iloc[start_index:end_index]
points_dataframe = points_dataframe.rename(columns={'start_lat': 'lat', 'start_lon': 'lng'})

points_geodataframe = gpd.GeoDataFrame(points_dataframe,
                                       geometry=gpd.points_from_xy(points_dataframe.lng,
                                         points_dataframe.lat))
points_geodataframe.crs = "EPSG:4326"  # For lat/lon data
joined = gpd.sjoin(points_geodataframe, cbg_gdf, how="left", predicate="within")

# count how many points fell in each CBG
counts = joined.groupby("L_HOOD").size().rename("point_count")  # GEOID or whatever your CBG id column is called

cbg_gdf = cbg_gdf.merge(counts, on="L_HOOD", how="left")
cbg_gdf["point_count"] = cbg_gdf["point_count"].fillna(0)

fig, ax = plt.subplots()

cbg_gdf.plot(
    column="point_count",
    cmap="Blues",           # light = low, dark = high
    edgecolor="black",
    linewidth=0.3,
    ax=ax,
    zorder=3,
    legend=True,
)

# ctx.add_basemap(ax, crs="EPSG:4326", source=ctx.providers.OpenStreetMap.Mapnik)

plt.setp(ax.get_xticklabels(), rotation=45, ha='right')
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.set_title("Starting Location by Neighborhood")
plt.show()

# %%
import geopandas as gpd

cbg_gdf = gpd.read_file("../data/Seattle_neighborhoods/nma_nhoods_main.shp")
cbg_gdf = cbg_gdf.to_crs("EPSG:4326")  # match your points' CRS

# print(cbg_gdf.columns.tolist())

# start_index = 0
# end_index = 10000
points_dataframe = pd.read_csv('../data/Spectus/Lyra_Processed/Seattle_2000_compressed_trips.csv')
points_dataframe = points_dataframe[points_dataframe['traj_id'] != -99]
# points_dataframe = points_dataframe.iloc[start_index:end_index]
points_dataframe = points_dataframe.rename(columns={'end_lat': 'lat', 'end_lon': 'lng'})

points_geodataframe = gpd.GeoDataFrame(points_dataframe,
                                       geometry=gpd.points_from_xy(points_dataframe.lng,
                                         points_dataframe.lat))
points_geodataframe.crs = "EPSG:4326"  # For lat/lon data
joined = gpd.sjoin(points_geodataframe, cbg_gdf, how="left", predicate="within")

# count how many points fell in each CBG
counts = joined.groupby("L_HOOD").size().rename("point_count")  # GEOID or whatever your CBG id column is called

cbg_gdf = cbg_gdf.merge(counts, on="L_HOOD", how="left")
cbg_gdf["point_count"] = cbg_gdf["point_count"].fillna(0)

fig, ax = plt.subplots()

cbg_gdf.plot(
    column="point_count",
    cmap="Blues",           # light = low, dark = high
    edgecolor="black",
    linewidth=0.3,
    ax=ax,
    zorder=3,
    legend=True,
)

# ctx.add_basemap(ax, crs="EPSG:4326", source=ctx.providers.OpenStreetMap.Mapnik)

plt.setp(ax.get_xticklabels(), rotation=45, ha='right')
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.set_title("End Location by Neighborhood")
plt.show()

# %%
import contextily as ctx
import geopandas as gpd
from matplotlib.collections import LineCollection
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from shapely.geometry import box, LineString

cbg_gdf = gpd.read_file("../data/Seattle_neighborhoods/nma_nhoods_main.shp")
cbg_gdf = cbg_gdf.to_crs("EPSG:4326")  # match your points' CRS

# print(cbg_gdf.columns.tolist())

# start_index = 0
# end_index = 10000
points_dataframe = pd.read_csv('~/Desktop/current/Seattle_2000_processed_data.csv')
points_dataframe = points_dataframe[points_dataframe['traj_id'] != -99]
# points_dataframe = points_dataframe.iloc[start_index:end_index]
points_dataframe = points_dataframe.rename(columns={'orig_lat': 'lat', 'orig_long': 'lng'})

points_geodataframe = gpd.GeoDataFrame(points_dataframe,
                                       geometry=gpd.points_from_xy(points_dataframe.lng,
                                         points_dataframe.lat))
points_geodataframe.crs = "EPSG:4326"  # For lat/lon data
joined = gpd.sjoin(points_geodataframe, cbg_gdf, how="left", predicate="within")

# count how many points fell in each CBG
counts = joined.groupby("L_HOOD").size().rename("point_count")  # GEOID or whatever your CBG id column is called

cbg_gdf = cbg_gdf.merge(counts, on="L_HOOD", how="left")
cbg_gdf["point_count"] = cbg_gdf["point_count"].fillna(0)

fig, ax = plt.subplots()

cbg_gdf.plot(
    column="point_count",
    cmap="Blues",           # light = low, dark = high
    edgecolor="black",
    linewidth=0.3,
    ax=ax,
    zorder=3,
    legend=True,
)

# ctx.add_basemap(ax, crs="EPSG:4326", source=ctx.providers.OpenStreetMap.Mapnik)

plt.setp(ax.get_xticklabels(), rotation=45, ha='right')
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.set_title("Datapoint Distribution by Neighborhood")
plt.show()
