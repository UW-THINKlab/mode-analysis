# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(3, 3, figsize=(18, 12))
# plt.rcParams['axes.titleweight'] = 'bold'
# plt.rcParams['axes.titlesize'] = 14
axes_flat = axes.flat

total_number_of_oservations = '1,316,907'
total_number_of_trips = '56,628'

ax8 = axes_flat[0]
ax8.text(0.5, 0.5, f"{total_number_of_oservations}", fontsize=40, ha='center', va='center')
ax8.set_title("Total Number of Records")
ax8.axis("off")  # removes ticks, box, etc.

ax9 = axes_flat[1]
ax9.text(0.5, 0.5, f"{total_number_of_trips}", fontsize=40, ha='center', va='center')
ax9.set_title("Total Number of Trips")
ax9.axis("off")
# Out:
# (np.float64(0.0), np.float64(1.0), np.float64(0.0), np.float64(1.0))

# %%
import matplotlib.pyplot as plt
import pandas as pd

ax = axes_flat[2]

root_path = 'data/'
file_name = 'database_metrics.csv'

df_rmove = pd.read_csv(f'{root_path}rMove/{file_name}')

filtered = df_rmove[df_rmove['number_of_records'] <= 200]
num_filtered = len(df_rmove[df_rmove['number_of_records'] > 200])
print(f'Filtered {num_filtered} records ({num_filtered / len(df_rmove) * 100.00}%)')
value_counts = filtered['number_of_records'].value_counts().sort_index()

median_val = filtered['number_of_records'].median()
p90_val = filtered['number_of_records'].quantile(0.90)

ax.hist(filtered['number_of_records'], bins=40, range=(0, 200), color= 'red', edgecolor='black')

ax.axvline(median_val, color='black', linestyle='--', linewidth=2, label=f'Median: {median_val:.0f}')
ax.axvline(p90_val, color='orange', linestyle='--', linewidth=2, label=f'P90: {p90_val:.0f}')
ax.legend()

ax.set_xlabel('Number of Records per Trip')
ax.set_ylabel('Number of Trips')
ax.set_title('Distribution of Number of Records per Trip')
# plt.show()

fig
# Out:
# Filtered 68 records (0.12008193826375646%)

# %%
import matplotlib.pyplot as plt
import pandas as pd

ax = axes_flat[3]

root_path = 'data/'
file_name = 'database_metrics.csv'

df_rmove = pd.read_csv(f'{root_path}rMove/{file_name}')

# filtered = df_rmove
filtered = df_rmove[df_rmove['total_distance_km'] <= 200.0]
num_filtered = len(df_rmove[df_rmove['total_distance_km'] > 200])
print(f'{num_filtered} records ({num_filtered / len(df_rmove) * 100.00}% of the total) have been omitted')
value_counts = filtered['total_distance_km'].value_counts().sort_index()

median_val = filtered['total_distance_km'].median()
p90_val = filtered['total_distance_km'].quantile(0.90)

# plt.figure(figsize=(10, 6))
ax.hist(filtered['total_distance_km'], bins=40, range=(0, 200), edgecolor='black')

ax.axvline(median_val, color='red', linestyle='--', linewidth=2, label=f'Median: {median_val:.0f}')
ax.axvline(p90_val, color='orange', linestyle='--', linewidth=2, label=f'P90: {p90_val:.0f}')
ax.legend()

ax.set_xlabel('Distance per Trip in km')
ax.set_ylabel('Number of Trips')
ax.set_title('Distribution of Trip Length (km)')
# plt.show()

fig
# Out:
# 207 records (0.36554354736172917% of the total) have been omitted

# %%
import matplotlib.pyplot as plt
import pandas as pd

ax = axes_flat[4]

root_path = 'data/'
file_name = 'database_metrics.csv'

df_rmove = pd.read_csv(f'{root_path}rMove/{file_name}')

# filtered = df_rmove
filtered = df_rmove[df_rmove['total_trip_time_minutes'] <= 400.0]
num_filtered = len(df_rmove[df_rmove['total_trip_time_minutes'] > 400])
print(f'{num_filtered} records ({num_filtered / len(df_rmove) * 100.00}% of the total) have been omitted')
value_counts = filtered['total_trip_time_minutes'].value_counts().sort_index()

median_val = filtered['total_trip_time_minutes'].median()
p90_val = filtered['total_trip_time_minutes'].quantile(0.90)

# plt.figure(figsize=(10, 6))
ax.hist(filtered['total_trip_time_minutes'], bins=40, range=(0, 400), color='green', edgecolor='black')

ax.axvline(median_val, color='red', linestyle='--', linewidth=2, label=f'Median: {median_val:.0f}')
ax.axvline(p90_val, color='orange', linestyle='--', linewidth=2, label=f'P90: {p90_val:.0f}')
ax.legend()

ax.set_xlabel('Minutes per Trip')
ax.set_ylabel('Number of Trips')
ax.set_title('Distribution of Trip Duration (min)')
# plt.show()

fig
# Out:
# 162 records (0.28607755880483154% of the total) have been omitted

# %%
import matplotlib.pyplot as plt
import pandas as pd

ax = axes_flat[5]

root_path = 'data/'
file_name = 'database_metrics.csv'

df_rmove = pd.read_csv(f'{root_path}rMove/{file_name}')

# filtered = df_rmove
filtered = df_rmove[df_rmove['density_records_per_minute'] <= 20.0]
num_filtered = len(df_rmove[df_rmove['density_records_per_minute'] > 20.0])
print(f'{num_filtered} trips ({num_filtered / len(df_rmove) * 100.00}% of the total) have been omitted')
value_counts = filtered['density_records_per_minute'].value_counts().sort_index()

p10_val = filtered['density_records_per_minute'].quantile(0.10)
median_val = filtered['density_records_per_minute'].median()
p90_val = filtered['density_records_per_minute'].quantile(0.90)

# plt.figure(figsize=(10, 6))
ax.hist(filtered['density_records_per_minute'], bins=40, range=(0, 20), color='purple', edgecolor='black')

ax.axvline(p10_val, color='lime', linestyle='--', linewidth=2, label=f'P10: {p10_val:.2f}')
ax.axvline(median_val, color='red', linestyle='--', linewidth=2, label=f'Median: {median_val:.2f}')
ax.axvline(p90_val, color='orange', linestyle='--', linewidth=2, label=f'P90: {p90_val:.2f}')
ax.legend()

ax.set_xlabel('Records per Minute')
ax.set_ylabel('Number of Trips')
ax.set_title('Distribution of Trip Density (Records per Minute)')
# plt.show()

fig
# Out:
# 1001 trips (1.7676767676767675% of the total) have been omitted

# %%
import matplotlib.pyplot as plt
import pandas as pd

ax = axes_flat[6]

root_path = 'data/'
file_name = 'database_metrics.csv'

df_rmove = pd.read_csv(f'{root_path}rMove/{file_name}')

filtered = df_rmove
value_counts = filtered['sparsity (per 5s)'].value_counts().sort_index()

p10_val = filtered['sparsity (per 5s)'].quantile(0.10)
median_val = filtered['sparsity (per 5s)'].median()
p90_val = filtered['sparsity (per 5s)'].quantile(0.90)

# plt.figure(figsize=(10, 6))
ax.hist(filtered['sparsity (per 5s)'], bins=50, range=(0.0, 1.0), color='grey', edgecolor='black')

ax.axvline(p10_val, color='lime', linestyle='--', linewidth=2, label=f'P10: {p10_val:.2f}')
ax.axvline(median_val, color='red', linestyle='--', linewidth=2, label=f'Median: {median_val:.2f}')
ax.axvline(p90_val, color='orange', linestyle='--', linewidth=2, label=f'P90: {p90_val:.2f}')
ax.legend()

ax.set_xlabel('Sparsity of Trip (% of intervals containing datapoints)')
ax.set_ylabel('Number of Trips')
ax.set_title('Distribution of Trip Sparsity (5s intervals)')
# plt.show()

fig

# %%
import matplotlib.pyplot as plt
import pandas as pd

ax = axes_flat[7]

root_path = 'data/'
file_name = 'database_metrics.csv'

df_rmove = pd.read_csv(f'{root_path}rMove/{file_name}')

filtered = df_rmove
value_counts = filtered['sparsity (per 30s)'].value_counts().sort_index()

p10_val = filtered['sparsity (per 30s)'].quantile(0.10)
median_val = filtered['sparsity (per 30s)'].median()
p90_val = filtered['sparsity (per 30s)'].quantile(0.90)

# plt.figure(figsize=(10, 6))
ax.hist(filtered['sparsity (per 30s)'], bins=50, range=(0.0, 1.0), color='grey', edgecolor='black')

ax.axvline(p10_val, color='lime', linestyle='--', linewidth=2, label=f'P10: {p10_val:.2f}')
ax.axvline(median_val, color='red', linestyle='--', linewidth=2, label=f'Median: {median_val:.2f}')
ax.axvline(p90_val, color='orange', linestyle='--', linewidth=2, label=f'P90: {p90_val:.2f}')
ax.legend()

ax.set_xlabel('Sparsity of Trip (% of intervals containing datapoints)')
ax.set_ylabel('Number of Trips')
ax.set_title('Distribution of Trip Sparsity (30s intervals)')
# plt.show()

fig

# %%
import matplotlib.pyplot as plt
import pandas as pd

ax = axes_flat[8]

root_path = 'data/'
file_name = 'database_metrics.csv'

df_rmove = pd.read_csv(f'{root_path}rMove/{file_name}')

filtered = df_rmove
value_counts = filtered['sparsity (per 1m)'].value_counts().sort_index()

p10_val = filtered['sparsity (per 1m)'].quantile(0.10)
median_val = filtered['sparsity (per 1m)'].median()
p90_val = filtered['sparsity (per 1m)'].quantile(0.90)

# plt.figure(figsize=(10, 6))
ax.hist(filtered['sparsity (per 1m)'], bins=50, range=(0.0, 1.0), color='grey', edgecolor='black')

ax.axvline(p10_val, color='lime', linestyle='--', linewidth=2, label=f'P10: {p10_val:.2f}')
ax.axvline(median_val, color='red', linestyle='--', linewidth=2, label=f'Median: {median_val:.2f}')
ax.axvline(p90_val, color='orange', linestyle='--', linewidth=2, label=f'P90: {p90_val:.2f}')
ax.legend()

ax.set_xlabel('Sparsity of Trip (% of intervals containing datapoints)')
ax.set_ylabel('Number of Trips')
ax.set_title('Distribution of Trip Sparsity (1m intervals)')
# plt.show()

fig

# %%
fig.tight_layout(rect=[0.01, 0.01, 0.99, 0.98])
fig.subplots_adjust(hspace=0.3)
fig.suptitle("rMove Dataset Metrics", fontsize=20, fontweight='bold', x=0.52, y=0.98)
fig.savefig("images/rMove_Grid.png", dpi=200)

fig
