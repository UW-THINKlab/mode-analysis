# %%
from src.process_files_rmove import pre_process_all_files_in_directory

pre_process_all_files_in_directory()

# %%
from src.plot import plot_all_trips_rMove_for_mode

plot_all_trips_rMove_for_mode('Walk', 0, 20)

# %%
from src.plot import plot_all_trips_rMove_for_mode

plot_all_trips_rMove_for_mode('Bike', 0, 20)

# %%
from src.plot import plot_all_trips_rMove_for_mode

plot_all_trips_rMove_for_mode('Drive SOV', 0, 20)

# %%
from src.plot import plot_all_trips_rMove_for_mode

plot_all_trips_rMove_for_mode('Drive HOV3+', 0, 60, with_average_and_max=True)

# %%
from src.plot import plot_all_trips_rMove_for_mode

plot_all_trips_rMove_for_mode('Transit', 0, 20)

# %%
from src.optimized_analysis import analyze_all_rMove

analyze_all_rMove(max_count=20000)

# %%
import pandas as pd

df = pd.read_csv("data/rMove/Household_Travel_Survey_Trips_-7221806773183684102.csv")
values = df["mode_1"].unique()

print(values)
