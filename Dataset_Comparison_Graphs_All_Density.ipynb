# %% [markdown]
# # Density across all Datasets

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, PercentFormatter

fig, axes = plt.subplots(3, 3, figsize=(18, 12))
axes_flat = axes.flat

# %%
import matplotlib.pyplot as plt
import pandas as pd

ax = axes_flat[0]

root_path = 'data/'
file_name = '20260714_geolife_database_metrics.csv'

df_geolife = pd.read_csv(f'{root_path}Geolife/{file_name}')
df_geolife = df_geolife[df_geolife['number_of_records'] > 0]

filtered = df_geolife[df_geolife['number_of_records'] <= 4000]
num_filtered = len(df_geolife[df_geolife['number_of_records'] > 4000])
percent_filtered = f'{num_filtered / len(df_geolife) * 100.00:.2f}'
print(f'Filtered {num_filtered} records ({percent_filtered}%)')
value_counts = filtered['number_of_records'].value_counts().sort_index()

p10_val = filtered['number_of_records'].quantile(0.10)
median_val = filtered['number_of_records'].median()
p90_val = filtered['number_of_records'].quantile(0.90)

# plt.figure(figsize=(10, 6))
ax.hist(filtered['number_of_records'], bins=40, range=(0, 4000), color='red', edgecolor='black')

ax.axvline(p10_val, color='lime', linestyle='--', linewidth=2, label=f'10th Percentile: {p10_val:.2f}')
ax.axvline(median_val, color='black', linestyle='--', linewidth=2, label=f'Median: {median_val:.0f}')
ax.axvline(p90_val, color='orange', linestyle='--', linewidth=2, label=f'90th Percentile: {p90_val:.2f}')
ax.legend(title=f"Outliers omitted: {num_filtered} ({percent_filtered}%)")

total_count = len(filtered['number_of_records'])
ax.yaxis.set_major_formatter(PercentFormatter(xmax=total_count, decimals=0))
ax.yaxis.set_major_locator(MultipleLocator(total_count * 0.05))
ax.set_xlabel('Number of Records per Trip')
ax.set_ylabel('Number of Trips')
ax.set_title('GeoLife - Distribution of Number of Records per Trip')
# plt.show()

fig
# Out:
# Filtered 140 records (1.46%)

# %%
import matplotlib.pyplot as plt
import pandas as pd

ax = axes_flat[1]

root_path = 'data/'
file_name = '20260714_geolife_database_metrics.csv'

df_geolife = pd.read_csv(f'{root_path}Geolife/{file_name}')
df_geolife = df_geolife[df_geolife['number_of_records'] > 0]

filtered = df_geolife[df_geolife['total_trip_time_minutes'] <= 400.0]
num_filtered = len(df_geolife[df_geolife['total_trip_time_minutes'] > 400])
percent_filtered = f'{num_filtered / len(df_geolife) * 100.00:.2f}'
print(f'Filtered {num_filtered} records ({percent_filtered}%)')
value_counts = filtered['total_trip_time_minutes'].value_counts().sort_index()

p10_val = filtered['total_trip_time_minutes'].quantile(0.10)
median_val = filtered['total_trip_time_minutes'].median()
p90_val = filtered['total_trip_time_minutes'].quantile(0.90)

# plt.figure(figsize=(10, 6))
ax.hist(filtered['total_trip_time_minutes'], bins=50, range=(0, 400), color='green', edgecolor='black')

ax.axvline(p10_val, color='lime', linestyle='--', linewidth=2, label=f'10th Percentile: {p10_val:.2f}')
ax.axvline(median_val, color='red', linestyle='--', linewidth=2, label=f'Median: {median_val:.0f}')
ax.axvline(p90_val, color='orange', linestyle='--', linewidth=2, label=f'90th Percentile: {p90_val:.0f}')
ax.legend(title=f"Outliers omitted: {num_filtered} ({percent_filtered}%)")

total_count = len(filtered['total_trip_time_minutes'])
ax.yaxis.set_major_formatter(PercentFormatter(xmax=total_count, decimals=0))
ax.yaxis.set_major_locator(MultipleLocator(total_count * 0.05))
ax.set_xlabel('Minutes per Trip')
ax.set_ylabel('Number of Trips')
ax.set_title('GeoLife - Distribution of Trip Duration (min)')
# plt.show()

fig
# Out:
# Filtered 153 records (1.59%)

# %%
import matplotlib.pyplot as plt
import pandas as pd

ax = axes_flat[2]

root_path = 'data/'
file_name = '20260714_geolife_database_metrics.csv'

df_geolife = pd.read_csv(f'{root_path}Geolife/{file_name}')
df_geolife = df_geolife[df_geolife['number_of_records'] > 0]

filtered = df_geolife[df_geolife['density_records_per_minute'] <= 200.0]
num_filtered = len(df_geolife[df_geolife['density_records_per_minute'] > 200.0])
percent_filtered = f'{num_filtered / len(df_geolife) * 100.00:.2f}'
print(f'Filtered {num_filtered} records ({percent_filtered}%)')
value_counts = filtered['density_records_per_minute'].value_counts().sort_index()

p10_val = filtered['density_records_per_minute'].quantile(0.10)
median_val = filtered['density_records_per_minute'].median()
p90_val = filtered['density_records_per_minute'].quantile(0.90)

# plt.figure(figsize=(10, 6))
ax.hist(filtered['density_records_per_minute'], bins=40, range=(0, 200), color='purple', edgecolor='black')

ax.axvline(p10_val, color='lime', linestyle='--', linewidth=2, label=f'10th Percentile: {p10_val:.2f}')
ax.axvline(median_val, color='red', linestyle='--', linewidth=2, label=f'Median: {median_val:.2f}')
ax.axvline(p90_val, color='orange', linestyle='--', linewidth=2, label=f'90th Percentile: {p90_val:.2f}')
ax.legend(title=f"Outliers omitted: {num_filtered} ({percent_filtered}%)")

total_count = len(filtered['density_records_per_minute'])
ax.yaxis.set_major_formatter(PercentFormatter(xmax=total_count, decimals=0))
ax.yaxis.set_major_locator(MultipleLocator(total_count * 0.05))
ax.set_xlabel('Records per Minute')
ax.set_ylabel('Number of Trips')
ax.set_title('GeoLife - Distribution of Trip Density (Records per Minute)')
# plt.show()

fig
# Out:
# Filtered 18 records (0.19%)

# %%
import matplotlib.pyplot as plt
import pandas as pd

ax = axes_flat[3]

root_path = 'data/'
file_name = '20260714_rmove_database_metrics.csv'

df_rmove = pd.read_csv(f'{root_path}rMove/{file_name}')

filtered = df_rmove[df_rmove['number_of_records'] <= 400]
num_filtered = len(df_rmove[df_rmove['number_of_records'] > 400])
percent_filtered = f'{num_filtered / len(df_rmove) * 100.00:.2f}'
print(f'Filtered {num_filtered} records ({percent_filtered}%)')
value_counts = filtered['number_of_records'].value_counts().sort_index()

p10_val = filtered['number_of_records'].quantile(0.10)
median_val = filtered['number_of_records'].median()
p90_val = filtered['number_of_records'].quantile(0.90)

ax.hist(filtered['number_of_records'], bins=40, range=(0, 400), color= 'red', edgecolor='black')

ax.axvline(p10_val, color='lime', linestyle='--', linewidth=2, label=f'10th Percentile: {p10_val:.2f}')
ax.axvline(median_val, color='black', linestyle='--', linewidth=2, label=f'Median: {median_val:.0f}')
ax.axvline(p90_val, color='orange', linestyle='--', linewidth=2, label=f'90th Percentile: {p90_val:.0f}')
ax.legend(title=f"Outliers omitted: {num_filtered} ({percent_filtered}%)")

total_count = len(filtered['number_of_records'])
ax.yaxis.set_major_formatter(PercentFormatter(xmax=total_count, decimals=0))
ax.yaxis.set_major_locator(MultipleLocator(total_count * 0.05))
ax.set_xlabel('Number of Records per Trip')
ax.set_ylabel('Number of Trips')
ax.set_title('rMove - Distribution of Number of Records per Trip')
# plt.show()

fig
# Out:
# Filtered 2 records (0.00%)

# %%
import matplotlib.pyplot as plt
import pandas as pd

ax = axes_flat[4]

root_path = 'data/'
file_name = '20260714_rmove_database_metrics.csv'

df_rmove = pd.read_csv(f'{root_path}rMove/{file_name}')

filtered = df_rmove[df_rmove['total_trip_time_minutes'] <= 400.0]
num_filtered = len(df_rmove[df_rmove['total_trip_time_minutes'] > 400])
percent_filtered = f'{num_filtered / len(df_rmove) * 100.00:.2f}'
print(f'Filtered {num_filtered} records ({percent_filtered}%)')
value_counts = filtered['total_trip_time_minutes'].value_counts().sort_index()

p10_val = filtered['total_trip_time_minutes'].quantile(0.10)
median_val = filtered['total_trip_time_minutes'].median()
p90_val = filtered['total_trip_time_minutes'].quantile(0.90)

# plt.figure(figsize=(10, 6))
ax.hist(filtered['total_trip_time_minutes'], bins=40, range=(0, 400), color='green', edgecolor='black')

ax.axvline(p10_val, color='lime', linestyle='--', linewidth=2, label=f'10th Percentile: {p10_val:.2f}')
ax.axvline(median_val, color='red', linestyle='--', linewidth=2, label=f'Median: {median_val:.0f}')
ax.axvline(p90_val, color='orange', linestyle='--', linewidth=2, label=f'90th Percentile: {p90_val:.0f}')
ax.legend(title=f"Outliers omitted: {num_filtered} ({percent_filtered}%)")

total_count = len(filtered['total_trip_time_minutes'])
ax.yaxis.set_major_formatter(PercentFormatter(xmax=total_count, decimals=0))
ax.yaxis.set_major_locator(MultipleLocator(total_count * 0.05))
ax.set_xlabel('Minutes per Trip')
ax.set_ylabel('Number of Trips')
ax.set_title('rMove - Distribution of Trip Duration (min)')
# plt.show()

fig
# Out:
# Filtered 162 records (0.29%)

# %%
import matplotlib.pyplot as plt
import pandas as pd

ax = axes_flat[5]

root_path = 'data/'
file_name = '20260714_rmove_database_metrics.csv'

df_rmove = pd.read_csv(f'{root_path}rMove/{file_name}')

filtered = df_rmove[df_rmove['density_records_per_minute'] <= 20.0]
num_filtered = len(df_rmove[df_rmove['density_records_per_minute'] > 20.0])
percent_filtered = f'{num_filtered / len(df_rmove) * 100.00:.2f}'
print(f'Filtered {num_filtered} records ({percent_filtered}%)')
value_counts = filtered['density_records_per_minute'].value_counts().sort_index()

p10_val = filtered['density_records_per_minute'].quantile(0.10)
median_val = filtered['density_records_per_minute'].median()
p90_val = filtered['density_records_per_minute'].quantile(0.90)

# plt.figure(figsize=(10, 6))
ax.hist(filtered['density_records_per_minute'], bins=40, range=(0, 20), color='purple', edgecolor='black')

ax.axvline(p10_val, color='lime', linestyle='--', linewidth=2, label=f'10th Percentile: {p10_val:.2f}')
ax.axvline(median_val, color='red', linestyle='--', linewidth=2, label=f'Median: {median_val:.2f}')
ax.axvline(p90_val, color='orange', linestyle='--', linewidth=2, label=f'90th Percentile: {p90_val:.2f}')
ax.legend(title=f"Outliers omitted: {num_filtered} ({percent_filtered}%)")

total_count = len(filtered['density_records_per_minute'])
ax.yaxis.set_major_formatter(PercentFormatter(xmax=total_count, decimals=0))
ax.yaxis.set_major_locator(MultipleLocator(total_count * 0.05))
ax.set_xlabel('Records per Minute')
ax.set_ylabel('Number of Trips')
ax.set_title('rMove - Distribution of Trip Density (Records per Minute)')
# plt.show()

fig
# Out:
# Filtered 1001 records (1.77%)

# %%
import matplotlib.pyplot as plt
import pandas as pd

ax = axes_flat[6]

df_spectus = pd.read_csv(f'./data/Spectus/Lyra_Processed/20260716_spectus_database_metrics.csv')
df_spectus = df_spectus[df_spectus['number_of_records'] > 0]

filtered = df_spectus[df_spectus['number_of_records'] <= 400]
num_filtered = len(df_spectus[df_spectus['number_of_records'] > 400])
percent_filtered = f'{num_filtered / len(df_spectus) * 100.00:.2f}'
print(f'Filtered {num_filtered} records ({percent_filtered}%)')
value_counts = filtered['number_of_records'].value_counts().sort_index()

p10_val = filtered['number_of_records'].quantile(0.10)
median_val = filtered['number_of_records'].median()
p90_val = filtered['number_of_records'].quantile(0.90)

# plt.figure(figsize=(10, 6))
ax.hist(filtered['number_of_records'], bins=40, range=(0, 400), color= 'red', edgecolor='black')

ax.axvline(p10_val, color='lime', linestyle='--', linewidth=2, label=f'10th Percentile: {p10_val:.2f}')
ax.axvline(median_val, color='black', linestyle='--', linewidth=2, label=f'Median: {median_val:.0f}')
ax.axvline(p90_val, color='orange', linestyle='--', linewidth=2, label=f'90th Percentile: {p90_val:.0f}')
ax.legend(title=f"Outliers omitted: {num_filtered} ({percent_filtered}%)")

total_count = len(filtered['number_of_records'])
ax.yaxis.set_major_formatter(PercentFormatter(xmax=total_count, decimals=0))
ax.yaxis.set_major_locator(MultipleLocator(total_count * 0.05))
ax.set_xlabel('Number of Records per Trip')
ax.set_ylabel('Number of Trips')
ax.set_title('Spectus - Distribution of Number of Records per Trip')
# plt.show()

fig
# Out:
# Filtered 1357 records (0.26%)

# %%
import matplotlib.pyplot as plt
import pandas as pd

ax = axes_flat[7]

df_spectus = pd.read_csv(f'./data/Spectus/Lyra_Processed/20260716_spectus_database_metrics.csv')

filtered = df_spectus[df_spectus['total_trip_time_minutes'] <= 400.0]
num_filtered = len(df_spectus[df_spectus['total_trip_time_minutes'] > 400])
percent_filtered = f'{num_filtered / len(df_spectus) * 100.00:.2f}'
print(f'Filtered {num_filtered} records ({percent_filtered}%)')
value_counts = filtered['total_trip_time_minutes'].value_counts().sort_index()

p10_val = filtered['total_trip_time_minutes'].quantile(0.10)
median_val = filtered['total_trip_time_minutes'].median()
p90_val = filtered['total_trip_time_minutes'].quantile(0.90)

# plt.figure(figsize=(10, 6))
ax.hist(filtered['total_trip_time_minutes'], bins=40, range=(0, 400), color='green', edgecolor='black')

ax.axvline(p10_val, color='lime', linestyle='--', linewidth=2, label=f'10th Percentile: {p10_val:.2f}')
ax.axvline(median_val, color='red', linestyle='--', linewidth=2, label=f'Median: {median_val:.0f}')
ax.axvline(p90_val, color='orange', linestyle='--', linewidth=2, label=f'90th Percentile: {p90_val:.0f}')
ax.legend(title=f"Outliers omitted: {num_filtered} ({percent_filtered}%)")

total_count = len(filtered['total_trip_time_minutes'])
ax.yaxis.set_major_formatter(PercentFormatter(xmax=total_count, decimals=0))
ax.yaxis.set_major_locator(MultipleLocator(total_count * 0.05))
ax.set_xlabel('Minutes per Trip')
ax.set_ylabel('Number of Trips')
ax.set_title('Spectus - Distribution of Trip Duration (min)')
# plt.show()

fig
# Out:
# Filtered 43 records (0.01%)

# %%
import matplotlib.pyplot as plt
import pandas as pd

ax = axes_flat[8]

df_spectus = pd.read_csv(f'./data/Spectus/Lyra_Processed/20260716_spectus_database_metrics.csv')

filtered = df_spectus[df_spectus['density_records_per_minute'] <= 20.0]
num_filtered = len(df_spectus[df_spectus['density_records_per_minute'] > 20.0])
percent_filtered = f'{num_filtered / len(df_spectus) * 100.00:.2f}'
print(f'Filtered {num_filtered} records ({percent_filtered}%)')
value_counts = filtered['density_records_per_minute'].value_counts().sort_index()

p10_val = filtered['density_records_per_minute'].quantile(0.10)
median_val = filtered['density_records_per_minute'].median()
p90_val = filtered['density_records_per_minute'].quantile(0.90)

# plt.figure(figsize=(10, 6))
ax.hist(filtered['density_records_per_minute'], bins=40, range=(0, 20), color='purple', edgecolor='black')

ax.axvline(p10_val, color='lime', linestyle='--', linewidth=2, label=f'10th Percentile: {p10_val:.2f}')
ax.axvline(median_val, color='red', linestyle='--', linewidth=2, label=f'Median: {median_val:.2f}')
ax.axvline(p90_val, color='orange', linestyle='--', linewidth=2, label=f'90th Percentile: {p90_val:.2f}')
ax.legend(title=f"Outliers omitted: {num_filtered} ({percent_filtered}%)")

total_count = len(filtered['density_records_per_minute'])
ax.yaxis.set_major_formatter(PercentFormatter(xmax=total_count, decimals=0))
ax.yaxis.set_major_locator(MultipleLocator(total_count * 0.05))
ax.set_xlabel('Records per Minute')
ax.set_ylabel('Number of Trips')
ax.set_title('Spectus - Distribution of Trip Density (Records per Minute)')
# plt.show()

fig
# Out:
# Filtered 623 records (0.12%)

# %%
fig.tight_layout(rect=[0.01, 0.01, 0.99, 0.98])
fig.subplots_adjust(hspace=0.3)
fig.suptitle("Density Across Datasets: GeoLife, rMove, and Spectus", fontsize=20, fontweight='bold', x=0.52, y=0.98)
fig.savefig("images/Density_Grid.png", dpi=200)

fig

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import numpy as np
import pandas as pd

fig2, axes2 = plt.subplots(2, 2, figsize=(12, 8), dpi=200)

axes2_flat = axes2.flatten()

df_geolife = pd.read_csv(f'./data/Geolife/20260726_geolife_database_metrics.csv')
df_geolife = df_geolife[df_geolife['number_of_records'] > 0]

df_rmove = pd.read_csv(f'./data/rMove/20260726_rmove_database_metrics.csv')
df_rmove = df_rmove[df_rmove['number_of_records'] > 0]

df_spectus = pd.read_csv(f'./data/Spectus/Lyra_Processed/20260726_spectus_database_metrics.csv')
df_spectus = df_spectus[df_spectus['number_of_records'] > 0]

# %%
ax2 = axes2_flat[0]

filtered_geolife = df_geolife
filtered_rmove = df_rmove
filtered_spectus = df_spectus

weights_geolife = np.ones_like(filtered_geolife['number_of_records']) / len(filtered_geolife['number_of_records']) * 100
weights_rmove = np.ones_like(filtered_rmove['number_of_records']) / len(filtered_rmove['number_of_records']) * 100
weights_spectus = np.ones_like(filtered_spectus['number_of_records']) / len(filtered_spectus['number_of_records']) * 100

median_geolife = filtered_geolife['number_of_records'].median()
median_rmove = filtered_rmove['number_of_records'].median()
median_spectus = filtered_spectus['number_of_records'].median()

ax2.axvline(median_geolife, color='C0', linestyle='--', linewidth=1, zorder=1)
ax2.axvline(median_rmove, color='C1', linestyle='--', linewidth=1, zorder=1)
ax2.axvline(median_spectus, color='C2', linestyle='--', linewidth=1, zorder=1)

ax2.hist(filtered_geolife['number_of_records'], bins=500, range=(0, 5000), alpha=0.5, label=f'GeoLife (median: {median_geolife:.0f})', weights=weights_geolife, zorder=2)
ax2.hist(filtered_rmove['number_of_records'], bins=500, range=(0, 5000), alpha=0.5, label=f'rMove (median: {median_rmove:.0f})', weights=weights_rmove, zorder=2)
ax2.hist(filtered_spectus['number_of_records'], bins=500, range=(0, 5000), alpha=0.5, label=f'Spectus (median: {median_spectus:.0f})', weights=weights_spectus, zorder=2)

ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_xlim(1, 5000)
ax2.set_ylim(0.01, 100)
ax2.tick_params(axis='y', which='minor', length=4, color='gray')
ax2.xaxis.set_major_formatter(ScalarFormatter())
ax2.yaxis.set_major_formatter(ScalarFormatter())

ax2.set_xlabel('Number of Records per Trip (log scale)')
ax2.set_ylabel('Percentage of Total (%, log scale)')
# ax2.set_title('Distribution of Number of Records per Trip')
ax2.legend()

fig2

# %%
ax2 = axes2_flat[1]

filtered_geolife = df_geolife[df_geolife['total_trip_time_minutes'] <= 1000]
filtered_rmove = df_rmove[df_rmove['total_trip_time_minutes'] <= 1000]
filtered_spectus = df_spectus[df_spectus['total_trip_time_minutes'] <= 1000]

weights_geolife = np.ones_like(filtered_geolife['total_trip_time_minutes']) / len(filtered_geolife['total_trip_time_minutes']) * 100
weights_rmove = np.ones_like(filtered_rmove['total_trip_time_minutes']) / len(filtered_rmove['total_trip_time_minutes']) * 100
weights_spectus = np.ones_like(filtered_spectus['total_trip_time_minutes']) / len(filtered_spectus['total_trip_time_minutes']) * 100

median_geolife = filtered_geolife['total_trip_time_minutes'].median()
median_rmove = filtered_rmove['total_trip_time_minutes'].median()
median_spectus = filtered_spectus['total_trip_time_minutes'].median()

ax2.axvline(median_geolife, color='C0', linestyle='--', linewidth=1, zorder=1)
ax2.axvline(median_rmove, color='C1', linestyle='--', linewidth=1, zorder=1)
ax2.axvline(median_spectus, color='C2', linestyle='--', linewidth=1, zorder=1)

ax2.hist(filtered_geolife['total_trip_time_minutes'], bins=1000, range=(0, 1000), alpha=0.5, label=f'GeoLife (median: {median_geolife:.0f})', weights=weights_geolife, zorder=2)
ax2.hist(filtered_rmove['total_trip_time_minutes'], bins=1000, range=(0, 1000), alpha=0.5, label=f'rMove (median: {median_rmove:.0f})', weights=weights_rmove, zorder=2)
ax2.hist(filtered_spectus['total_trip_time_minutes'], bins=1000, range=(0, 1000), alpha=0.5, label=f'Spectus (median: {median_spectus:.0f})', weights=weights_spectus, zorder=2)

ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_xlim(0.1, 1000)
ax2.set_ylim(0.01, 100)
ax2.xaxis.set_major_formatter(ScalarFormatter())
ax2.yaxis.set_major_formatter(ScalarFormatter())

ax2.set_xlabel('Trip Duration (mins, log scale)')
ax2.set_ylabel('Percentage of Total (%, log scale)')
# ax2.set_title('Distribution of Trip Duration (mins)')
ax2.legend()

fig2

# %%
# ax2 = axes2_flat[2]
#
# filtered_geolife = df_geolife[df_geolife['total_distance_km'] <= 1000]
# filtered_rmove = df_rmove[df_rmove['total_distance_km'] <= 1000]
# filtered_spectus = df_spectus[df_spectus['total_distance_km'] <= 1000]
#
# weights_geolife = np.ones_like(filtered_geolife['total_distance_km']) / len(filtered_geolife['total_distance_km']) * 100
# weights_rmove = np.ones_like(filtered_rmove['total_distance_km']) / len(filtered_rmove['total_distance_km']) * 100
# weights_spectus = np.ones_like(filtered_spectus['total_distance_km']) / len(filtered_spectus['total_distance_km']) * 100
#
# median_geolife = filtered_geolife['total_distance_km'].median()
# median_rmove = filtered_rmove['total_distance_km'].median()
# median_spectus = filtered_spectus['total_distance_km'].median()
#
# ax2.axvline(median_geolife, color='C0', linestyle='--', linewidth=1, zorder=1)
# ax2.axvline(median_rmove, color='C1', linestyle='--', linewidth=1, zorder=1)
# ax2.axvline(median_spectus, color='C2', linestyle='--', linewidth=1, zorder=1)
#
# ax2.hist(filtered_geolife['total_distance_km'], bins=1000, range=(0, 1000), alpha=0.5, label=f'GeoLife (median: {median_geolife:.0f})', weights=weights_geolife, zorder=2)
# ax2.hist(filtered_rmove['total_distance_km'], bins=1000, range=(0, 1000), alpha=0.5, label=f'rMove (median: {median_rmove:.0f})', weights=weights_rmove, zorder=2)
# ax2.hist(filtered_spectus['total_distance_km'], bins=1000, range=(0, 1000), alpha=0.5, label=f'Spectus (median: {median_spectus:.0f})', weights=weights_spectus, zorder=2)
#
# ax2.set_xscale('log')
# ax2.set_yscale('log')
# ax2.set_xlim(0.1, 1000)
# ax2.set_ylim(0.01, 100)
# ax2.xaxis.set_major_formatter(ScalarFormatter())
# ax2.yaxis.set_major_formatter(ScalarFormatter())
#
# ax2.set_xlabel('Trip Distance (km, log scale)')
# ax2.set_ylabel('Percentage of Total (%, log scale)')
# # ax2.set_title('Distribution of Trip Distance (km)')
# ax2.legend()
#
# fig2

ax2 = axes2_flat[2]

filtered_geolife = pd.read_csv(f'./data/Geolife/20260727_geolife_per_day_averages.csv', low_memory=False)
filtered_rmove = pd.read_csv(f'./data/rMove/20260727_rmove_per_day_averages.csv', low_memory=False)
filtered_spectus = pd.read_csv(f'./data/Spectus/Lyra_Processed/20260727_spectus_per_day_averages.csv', low_memory=False)

weights_geolife = np.ones_like(filtered_geolife['trips_per_day_for_measured_days']) / len(filtered_geolife['trips_per_day_for_measured_days']) * 100
weights_rmove = np.ones_like(filtered_rmove['trips_per_day_for_measured_days']) / len(filtered_rmove['trips_per_day_for_measured_days']) * 100
weights_spectus = np.ones_like(filtered_spectus['trips_per_day_for_measured_days']) / len(filtered_spectus['trips_per_day_for_measured_days']) * 100

median_geolife = filtered_geolife['trips_per_day_for_measured_days'].median()
median_rmove = filtered_rmove['trips_per_day_for_measured_days'].median()
median_spectus = filtered_spectus['trips_per_day_for_measured_days'].median()

ax2.axvline(median_geolife, color='C0', linestyle='--', linewidth=1, zorder=1)
ax2.axvline(median_rmove, color='C1', linestyle='--', linewidth=1, zorder=1)
ax2.axvline(median_spectus, color='C2', linestyle='--', linewidth=1, zorder=1)

ax2.hist(filtered_geolife['trips_per_day_for_measured_days'], bins=60, range=(0, 30), alpha=0.5, label=f'GeoLife (median: {median_geolife:.1f})', weights=weights_geolife, zorder=2)
ax2.hist(filtered_rmove['trips_per_day_for_measured_days'], bins=60, range=(0, 30), alpha=0.5, label=f'rMove (median: {median_rmove:.1f})', weights=weights_rmove, zorder=2)
ax2.hist(filtered_spectus['trips_per_day_for_measured_days'], bins=60, range=(0, 30), alpha=0.5, label=f'Spectus (median: {median_spectus:.1f})', weights=weights_spectus, zorder=2)

ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_xlim(0.8, 30)
ax2.set_ylim(0.01, 100)
ax2.tick_params(axis='y', which='minor', length=4, color='gray')
ax2.xaxis.set_major_formatter(ScalarFormatter())
ax2.yaxis.set_major_formatter(ScalarFormatter())

ax2.set_xlabel('Average Trips per Measured Day, per User (log scale)')
ax2.set_ylabel('Percentage of Total (%)')
# ax2.set_title('Distribution of Trips per Day, per User (Measured Days)')
ax2.legend()

fig2

# %%
ax2 = axes2_flat[3]

filtered_geolife = df_geolife[df_geolife['density_records_per_minute'] <= 200]
filtered_rmove = df_rmove[df_rmove['density_records_per_minute'] <= 200]
filtered_spectus = df_spectus[df_spectus['density_records_per_minute'] <= 200]

weights_geolife = np.ones_like(filtered_geolife['density_records_per_minute']) / len(filtered_geolife['density_records_per_minute']) * 100
weights_rmove = np.ones_like(filtered_rmove['density_records_per_minute']) / len(filtered_rmove['density_records_per_minute']) * 100
weights_spectus = np.ones_like(filtered_spectus['density_records_per_minute']) / len(filtered_spectus['density_records_per_minute']) * 100

median_geolife = filtered_geolife['density_records_per_minute'].median()
median_rmove = filtered_rmove['density_records_per_minute'].median()
median_spectus = filtered_spectus['density_records_per_minute'].median()

ax2.axvline(median_geolife, color='C0', linestyle='--', linewidth=1, zorder=1)
ax2.axvline(median_rmove, color='C1', linestyle='--', linewidth=1, zorder=1)
ax2.axvline(median_spectus, color='C2', linestyle='--', linewidth=1, zorder=1)

ax2.hist(filtered_geolife['density_records_per_minute'], bins=2000, range=(0, 200), alpha=0.5, label=f'GeoLife (median: {median_geolife:.0f})', weights=weights_geolife, zorder=2)
ax2.hist(filtered_rmove['density_records_per_minute'], bins=2000, range=(0, 200), alpha=0.5, label=f'rMove (median: {median_rmove:.0f})', weights=weights_rmove, zorder=2)
ax2.hist(filtered_spectus['density_records_per_minute'], bins=2000, range=(0, 200), alpha=0.5, label=f'Spectus (median: {median_spectus:.0f})', weights=weights_spectus, zorder=2)

ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_xlim(0.1, 200)
ax2.set_ylim(0.01, 100)
ax2.tick_params(axis='y', which='minor', length=4, color='gray')
ax2.xaxis.set_major_formatter(ScalarFormatter())
ax2.yaxis.set_major_formatter(ScalarFormatter())

ax2.set_xlabel('Trip Density (Average Records per Minute, log scale)')
ax2.set_ylabel('Percentage of Total (%, log scale)')
# ax2.set_title('Distribution of Trip Density (Records per Minute)')
ax2.legend()

fig2

# %%
for ax in axes2_flat:
    ax.xaxis.label.set_fontsize(13)
    ax.yaxis.label.set_fontsize(13)

labels = ['a', 'b', 'c', 'd']
for ax, label in zip(axes2_flat, labels):
    # Place label in the upper-left corner of each subplot
    ax.text(
        0.02, 0.90,          # x, y in axes coordinates
        f'({label})',         # e.g. (a), (b), ...
        transform=ax.transAxes,
        fontsize=14,
        fontweight='bold',
        va='bottom',
        ha='left',
        # bbox=dict(facecolor='white', edgecolor='gray', boxstyle='square,pad=0.2')
    )

# fig2.suptitle("Density Comparison: GeoLife, rMove, and Spectus", fontsize=20, fontweight='bold', x=0.52, y=0.98)

fig2.tight_layout(rect=[0.01, 0.01, 0.99, 0.98])
fig2.subplots_adjust(hspace=0.3)
fig2.savefig("images/Overlapped_Density_Graphs.png", dpi=200)

fig2
